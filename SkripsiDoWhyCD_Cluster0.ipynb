# %%
# !pip install dowhy
# !pip install networkx
# Out:
# Collecting dowhy
#   Downloading dowhy-0.14-py3-none-any.whl.metadata (18 kB)
# Collecting causal-learn>=0.1.3.0 (from dowhy)
#   Downloading causal_learn-0.1.4.7-py3-none-any.whl.metadata (4.8 kB)
# Collecting cvxpy<2.0.0,>=1.7.1 (from dowhy)
#   Downloading cvxpy-1.9.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: cython>=3.0 in /usr/local/lib/python3.12/dist-packages (from dowhy) (3.0.12)
# Requirement already satisfied: joblib>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from dowhy) (1.5.3)
# Requirement already satisfied: networkx>=3.3 in /usr/local/lib/python3.12/dist-packages (from dowhy) (3.6.1)
# Requirement already satisfied: numba>=0.59 in /usr/local/lib/python3.12/dist-packages (from dowhy) (0.60.0)
# Requirement already satisfied: numpy>2.0 in /usr/local/lib/python3.12/dist-packages (from dowhy) (2.0.2)
# Requirement already satisfied: pandas>1.0 in /usr/local/lib/python3.12/dist-packages (from dowhy) (2.2.2)
# Requirement already satisfied: scikit-learn>1.0 in /usr/local/lib/python3.12/dist-packages (from dowhy) (1.6.1)
# Collecting scipy<=1.15.3 (from dowhy)
#   Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 713.2 kB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.14 in /usr/local/lib/python3.12/dist-packages (from dowhy) (0.14.6)
# Requirement already satisfied: sympy>=1.10.1 in /usr/local/lib/python3.12/dist-packages (from dowhy) (1.14.0)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.12/dist-packages (from dowhy) (4.67.3)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from causal-learn>=0.1.3.0->dowhy) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from causal-learn>=0.1.3.0->dowhy) (3.10.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from causal-learn>=0.1.3.0->dowhy) (4.0.1)
# Collecting momentchi2 (from causal-learn>=0.1.3.0->dowhy)
#   Downloading momentchi2-0.1.8-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: osqp>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (1.1.3)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/lib/python3.12/dist-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (3.2.11)
# Requirement already satisfied: highspy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from cvxpy<2.0.0,>=1.7.1->dowhy) (1.14.0)
# Collecting qdldl>=0.1.7.post0 (from cvxpy<2.0.0,>=1.7.1->dowhy)
#   Downloading qdldl-0.1.9.post1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (1.9 kB)
# Collecting sparsediffpy<0.4.0,>=0.3.0 (from cvxpy<2.0.0,>=1.7.1->dowhy)
#   Downloading sparsediffpy-0.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (581 bytes)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.59->dowhy) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>1.0->dowhy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>1.0->dowhy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>1.0->dowhy) (2026.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>1.0->dowhy) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14->dowhy) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14->dowhy) (26.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.10.1->dowhy) (1.3.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from clarabel>=0.5.0->cvxpy<2.0.0,>=1.7.1->dowhy) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy) (75.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>1.0->dowhy) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->causal-learn>=0.1.3.0->dowhy) (3.3.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->clarabel>=0.5.0->cvxpy<2.0.0,>=1.7.1->dowhy) (3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy) (3.0.3)
# Downloading dowhy-0.14-py3-none-any.whl (403 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 403.1/403.1 kB 4.0 MB/s eta 0:00:00
# Downloading causal_learn-0.1.4.7-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.5/245.5 kB 14.8 MB/s eta 0:00:00
# Downloading cvxpy-1.9.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 28.3 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 39.2 MB/s eta 0:00:00
# Downloading qdldl-0.1.9.post1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 75.4 MB/s eta 0:00:00
# Downloading sparsediffpy-0.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 60.3 MB/s eta 0:00:00
# Downloading momentchi2-0.1.8-py3-none-any.whl (11 kB)
# Installing collected packages: sparsediffpy, scipy, qdldl, momentchi2, cvxpy, causal-learn, dowhy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: cvxpy
#     Found existing installation: cvxpy 1.6.7
#     Uninstalling cvxpy-1.6.7:
#       Successfully uninstalled cvxpy-1.6.7
# Successfully installed causal-learn-0.1.4.7 cvxpy-1.9.2 dowhy-0.14 momentchi2-0.1.8 qdldl-0.1.9.post1 scipy-1.15.3 sparsediffpy-0.3.0
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (3.6.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
project_path = "/content/drive/MyDrive/Colab Notebooks/CD Skripsi"

# %%
import networkx as nx
from dowhy import gcm
import pandas as pd
import numpy as np

# %%
# Set seed
np.random.seed(42)

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CD Skripsi/EdgesDAG - Cluster 0_PD2.5.csv')

data
# Out:
#     No.                      Node 1 Interaction              Node 2  Ensemble  \
# 0     1              delivery_delay         -->  late_delivery_flag     1.000
# 1     2               freight_value         -->     is_dissatisfied     1.000
# 2     3               total_payment         -->       delivery_time     1.000
# 3     4               total_payment         -->         no_delivery     1.000
# 4     5               delivery_time         -->  late_delivery_flag     1.000
# 5     6               freight_value         -->       delivery_time     1.000
# 6     7          late_delivery_flag         -->     is_dissatisfied     1.000
# 7     8  product_description_length         -->       total_payment     1.000
# 8     9          product_photos_qty         -->       total_payment     1.000
# 9    10            avg_installments         -->       total_payment     1.000
# 10   11               delivery_time         -->     is_dissatisfied     0.998
# 11   12  product_description_length         ---  product_photos_qty     0.997
# 12   13               freight_value         -->         no_delivery     0.983
# 13   14               total_payment         -->        cancellation     0.853
# 14   15               total_payment         -->       freight_value     0.810
# 15   16                 no_delivery         -->        cancellation     0.804
# 16   17              delivery_delay         -->       delivery_time     0.790
# 17   18          product_photos_qty         -->       delivery_time     0.785
# 18   19               freight_value         -->      delivery_delay     0.709
# 19   20            avg_installments         -->         no_delivery     0.641
#
#      Edge  No edge  --> dd pl  <-- dd pl    ---  --> pd nl  <-- pd nl  \
# 0   1.000      NaN        NaN        NaN    NaN        NaN        NaN
# 1   1.000      NaN        NaN        NaN    NaN        NaN        NaN
# 2   1.000      NaN        NaN        NaN    NaN        NaN        NaN
# 3   1.000      NaN        NaN        NaN    NaN        NaN        NaN
# 4   1.000      NaN        NaN        NaN    NaN      1.000        NaN
# 5   1.000      NaN      1.000        NaN    NaN        NaN        NaN
# 6   1.000      NaN        NaN        NaN    NaN      1.000        NaN
# 7   1.000      NaN      1.000        NaN    NaN        NaN        NaN
# 8   1.000      NaN      1.000        NaN    NaN        NaN        NaN
# 9   1.000      NaN      1.000        NaN    NaN        NaN        NaN
# 10  0.998    0.002        NaN        NaN    NaN        NaN        NaN
# 11  1.000      NaN      0.003        NaN  0.997        NaN        NaN
# 12  0.983    0.017      0.983        NaN    NaN        NaN        NaN
# 13  0.853    0.147        NaN        NaN    NaN      0.853        NaN
# 14  1.000      NaN        NaN       0.19    NaN      0.810        NaN
# 15  1.000      NaN        NaN        NaN    NaN      0.804      0.196
# 16  1.000      NaN      0.790        NaN    NaN        NaN      0.210
# 17  0.785    0.215      0.785        NaN    NaN        NaN        NaN
# 18  0.709    0.291        NaN        NaN    NaN      0.709        NaN
# 19  0.641    0.359      0.641        NaN    NaN        NaN        NaN
#
#     --> dd nl  <-- dd nl  o->  <-o  o-o  <->
# 0       1.000        NaN  NaN  NaN  NaN  NaN
# 1       1.000        NaN  NaN  NaN  NaN  NaN
# 2       1.000        NaN  NaN  NaN  NaN  NaN
# 3       1.000        NaN  NaN  NaN  NaN  NaN
# 4         NaN        NaN  NaN  NaN  NaN  NaN
# 5         NaN        NaN  NaN  NaN  NaN  NaN
# 6         NaN        NaN  NaN  NaN  NaN  NaN
# 7         NaN        NaN  NaN  NaN  NaN  NaN
# 8         NaN        NaN  NaN  NaN  NaN  NaN
# 9         NaN        NaN  NaN  NaN  NaN  NaN
# 10      0.998        NaN  NaN  NaN  NaN  NaN
# 11        NaN        NaN  NaN  NaN  NaN  NaN
# 12        NaN        NaN  NaN  NaN  NaN  NaN
# 13        NaN        NaN  NaN  NaN  NaN  NaN
# 14        NaN        NaN  NaN  NaN  NaN  NaN
# 15        NaN        NaN  NaN  NaN  NaN  NaN
# 16        NaN        NaN  NaN  NaN  NaN  NaN
# 17        NaN        NaN  NaN  NaN  NaN  NaN
# 18        NaN        NaN  NaN  NaN  NaN  NaN
# 19        NaN        NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# #DoWhy

# %%
data_cluster0 = pd.read_csv(
    '/content/drive/MyDrive/Colab Notebooks/CD Skripsi/causal_cluster_0.csv',
    sep=',',
    engine='python'
)

data_cluster0.head()
# Out:
#    cancellation  no_delivery  delivery_delay  delivery_time  \
# 0           0.0          0.0            -8.0           13.0
# 1           0.0          0.0           -10.0           16.0
# 2           0.0          0.0           -16.0            4.0
# 3           0.0          0.0           -14.0            8.0
# 4           0.0          0.0           -19.0           14.0
#
#    late_delivery_flag  avg_installments  total_payment  freight_value  \
# 0                 0.0               6.0        196.890          16.89
# 1                 0.0               3.0        348.955          37.18
# 2                 0.0               4.0        257.440          27.64
# 3                 0.0               1.0        348.955          38.94
# 4                 0.0              10.0        325.930          26.93
#
#    product_description_length  product_photos_qty  is_dissatisfied
# 0                       794.0                 3.0                0
# 1                       190.0                 1.0                1
# 2                       177.5                 1.0                1
# 3                       347.0                 1.0                0
# 4                       744.0                 1.0                1

# %%
graph = nx.DiGraph()
graph.add_edges_from([
    ('delivery_delay', 'late_delivery_flag'),
        ('freight_value', 'is_dissatisfied'),
        ('total_payment', 'delivery_time'),
        ('total_payment', 'no_delivery'),
        ('delivery_time', 'late_delivery_flag'),
        ('freight_value', 'delivery_time'),
        ('late_delivery_flag', 'is_dissatisfied'),
        ('product_description_length', 'total_payment'),
        ('product_photos_qty', 'total_payment'),
        ('avg_installments', 'total_payment'),
        ('delivery_time', 'is_dissatisfied'),
        ('freight_value', 'no_delivery'),
        ('total_payment', 'cancellation'),
        ('total_payment', 'freight_value'),
        ('no_delivery', 'cancellation'),
        ('delivery_delay', 'delivery_time'),
        ('product_photos_qty', 'delivery_time'),
        ('freight_value', 'delivery_delay'),
        ('avg_installments', 'no_delivery')
])

# %%
causal_model = gcm.StructuralCausalModel(graph)

# %%
gcm.auto.assign_causal_mechanisms(causal_model, data_cluster0)

# %%
gcm.fit(causal_model, data_cluster0)
# Out:
# Fitting causal mechanism of node cancellation: 100%|██████████| 11/11 [00:01<00:00,  5.79it/s]

# %%
validation_summary = gcm.evaluate_causal_model(causal_model, data_cluster0)
validation_summary
# Out:
# Evaluating causal mechanisms...: 100%|██████████| 11/11 [01:45<00:00,  9.57s/it]
# Test permutations of given graph: 100%|██████████| 50/50 [05:40<00:00,  6.81s/it]
# CausalModelEvaluationResult(mechanism_performances={'product_description_length': MechanismPerformanceResult(), 'product_photos_qty': MechanismPerformanceResult(), 'avg_installments': MechanismPerformanceResult(), 'total_payment': MechanismPerformanceResult(), 'freight_value': MechanismPerformanceResult(), 'no_delivery': MechanismPerformanceResult(), 'delivery_delay': MechanismPerformanceResult(), 'cancellation': MechanismPerformanceResult(), 'delivery_time': MechanismPerformanceResult(), 'late_delivery_flag': MechanismPerformanceResult(), 'is_dissatisfied': MechanismPerformanceResult()}, pnl_assumptions={'delivery_delay': (np.float64(1.0), np.False_, 0.05), 'late_delivery_flag': (np.float64(0.0), np.True_, 0.05), 'freight_value': (np.float64(1.0), np.False_, 0.05), 'is_dissatisfied': (np.float64(0.0), np.True_, 0.05), 'total_payment': (np.float64(1.0), np.False_, 0.05), 'delivery_time': (np.float64(4.77386184360995e-06), np.True_, 0.05), 'no_delivery': (np.float64(0.0), np.True_, 0.05), 'cancellation': (np.float64(0.0), np.True_, 0.05)}, graph_falsification=+-------------------------------------------------------------------------------------------------------+
# |                                         Falsification Summary                                         |
# +-------------------------------------------------------------------------------------------------------+
# | The given DAG is informative because 0 / 50 of the permutations lie in the Markov                     |
# | equivalence class of the given DAG (p-value: 0.00).                                                   |
# | The given DAG violates 6/47 LMCs and is better than 98.0% of the permuted DAGs (p-value: 0.02).       |
# | Based on the provided significance level (0.2) and because the DAG is informative,                    |
# | we do not reject the DAG.                                                                             |
# +-------------------------------------------------------------------------------------------------------+, overall_kl_divergence=np.float64(4.9337255293525635), plot_falsification_histogram=True)

# %%
# BASELINE SAMPLE
baseline=(data_cluster0["is_dissatisfied"].mean())
print("baseline_dissatisfaction")
baseline
# Out:
# baseline_dissatisfaction
# np.float64(0.17174616747083613)

# %% [markdown]
# intervensi

# %%
# INTERVENSI 1
# TURUNKAN ONGKIR
int_freight = gcm.interventional_samples(
    causal_model,
    interventions={
        "freight_value": lambda x: x * 0.9
    },
    observed_data = data_cluster0
)

# %%
print("is_dissatisfied intervention:")
print(data_cluster0["is_dissatisfied"].mean())
# Out:
# is_dissatisfied intervention:
# 0.17174616747083613

# %%
print("after intervention")
print(int_freight["is_dissatisfied"].mean())
# Out:
# after intervention
# 0.17931961155560985

# %%
comparison = pd.DataFrame({
    "Variabel": ["freight_value", "is_dissatisfied"],
    "Sebelum": [
        data_cluster0["freight_value"].mean(),
        data_cluster0["is_dissatisfied"].mean()
    ],
    "Sesudah": [
        int_freight["freight_value"].mean(),
        int_freight["is_dissatisfied"].mean()
    ]
})

comparison["Efek Intervensi"] = comparison["Sesudah"] - comparison["Sebelum"]

comparison
# Out:
#           Variabel    Sebelum    Sesudah  Efek Intervensi
# 0    freight_value  28.185662  25.353494        -2.832169
# 1  is_dissatisfied   0.171746   0.179320         0.007573

# %%
# INTERVENSI 2
# PERCEPAT PENGIRIMAN
# delivery time turun 10%
int_delivery = gcm.interventional_samples(
    causal_model,
    interventions={
        "delivery_time": lambda x: x * 0.9
    },
    observed_data = data_cluster0
)

# %%
print("is_dissatisfied intervention:")
print(data_cluster0["is_dissatisfied"].mean())
# Out:
# is_dissatisfied intervention:
# 0.17174616747083613

# %%
print("after intervention:")
print(int_delivery["is_dissatisfied"].mean())
# Out:
# after intervention:
# 0.1685091308862151

# %%
comparison = pd.DataFrame({
    "Variabel": ["delivery_time", "is_dissatisfied"],
    "Sebelum": [
        data_cluster0["delivery_time"].mean(),
        data_cluster0["is_dissatisfied"].mean()
    ],
    "Sesudah": [
        int_delivery["delivery_time"].mean(),
        int_delivery["is_dissatisfied"].mean()
    ]
})

comparison["Efek Intervensi"] = comparison["Sesudah"] - comparison["Sebelum"]

comparison
# Out:
#           Variabel    Sebelum    Sesudah  Efek Intervensi
# 0    delivery_time  13.896109  12.561852        -1.334258
# 1  is_dissatisfied   0.171746   0.168509        -0.003237

# %%
# INTERVENSI 3 (late_delivery_flag)
int_late = gcm.interventional_samples(
    causal_model,
    interventions={
        "late_delivery_flag": lambda x: x * 0.9
    },
    observed_data = data_cluster0
)

# %%
print("is_dissatisfied intervention:")
print(data_cluster0["is_dissatisfied"].mean())
# Out:
# is_dissatisfied intervention:
# 0.17174616747083613

# %%
print("after intervention:")
print(int_late["is_dissatisfied"].mean())
# Out:
# after intervention:
# 0.16973065412569474

# %%
comparison = pd.DataFrame({
    "Variabel": ["late_delivery_flag", "is_dissatisfied"],
    "Sebelum": [
        data_cluster0["late_delivery_flag"].mean(),
        data_cluster0["is_dissatisfied"].mean()
    ],
    "Sesudah": [
        int_late["late_delivery_flag"].mean(),
        int_late["is_dissatisfied"].mean()
    ]
})

comparison["Efek Intervensi"] = comparison["Sesudah"] - comparison["Sebelum"]

comparison
# Out:
#              Variabel   Sebelum   Sesudah  Efek Intervensi
# 0  late_delivery_flag  0.082636  0.074363        -0.008273
# 1     is_dissatisfied  0.171746  0.169731        -0.002016

# %%
# RINGKASAN
summary = pd.DataFrame({
    "Scenario": [
        "Baseline",
        "Freight Value ↓",
        "Delivery Time ↓",
        "late_delivery_flag ↓",
    ],
    "Mean_is_dissatisfied": [
        baseline.mean(),
        int_freight["is_dissatisfied"].mean(),
        int_delivery["is_dissatisfied"].mean(),
        int_late["is_dissatisfied"].mean(),
    ]
})

display(summary)
# Out:
#                Scenario  Mean_is_dissatisfied
# 0              Baseline              0.171746
# 1       Freight Value ↓              0.179320
# 2       Delivery Time ↓              0.168509
# 3  late_delivery_flag ↓              0.169731
